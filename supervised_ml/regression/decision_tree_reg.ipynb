# %% [markdown]
# <h3>Decision Tree Regression</h3>

# %%
import pandas as pd 
import numpy as np 
import seaborn as sb
import matplotlib.pyplot as plt 
from sklearn.datasets import fetch_california_housing
from sklearn.preprocessing import StandardScaler

dataset  = fetch_california_housing()
df=pd.DataFrame(dataset.data,columns=dataset.feature_names)
df['price(in mil)'] = dataset.target
sc = StandardScaler()
X = df.iloc[:,:-1]
X = sc.fit_transform(X)
y = df.iloc[:,-1]

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=7)
dtr = DecisionTreeRegressor(criterion='friedman_mse',max_depth=4,max_features='log2',splitter='random')
dtr.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='friedman_mse', max_depth=4,
#                       max_features='log2', splitter='random')

# %%
from sklearn import tree
plt.figure(figsize=(20,20))
tree.plot_tree(dtr,filled=True)
# Out:
# [Text(0.5446428571428571, 0.9, 'x[1] <= 0.561\nfriedman_mse = 1.328\nsamples = 16512\nvalue = 2.059'),
#  Text(0.2857142857142857, 0.7, 'x[2] <= 6.144\nfriedman_mse = 1.209\nsamples = 11432\nvalue = 2.008'),
#  Text(0.14285714285714285, 0.5, 'x[7] <= -0.21\nfriedman_mse = 1.21\nsamples = 11378\nvalue = 2.01'),
#  Text(0.07142857142857142, 0.3, 'x[7] <= -0.453\nfriedman_mse = 1.196\nsamples = 4398\nvalue = 1.971'),
#  Text(0.03571428571428571, 0.1, 'friedman_mse = 1.213\nsamples = 4107\nvalue = 2.018'),
#  Text(0.10714285714285714, 0.1, 'friedman_mse = 0.498\nsamples = 291\nvalue = 1.315'),
#  Text(0.21428571428571427, 0.3, 'x[0] <= 5.382\nfriedman_mse = 1.218\nsamples = 6980\nvalue = 2.034'),
#  Text(0.17857142857142858, 0.1, 'friedman_mse = 1.207\nsamples = 6970\nvalue = 2.029'),
#  Text(0.25, 0.1, 'friedman_mse = -0.0\nsamples = 10\nvalue = 5.0'),
#  Text(0.42857142857142855, 0.5, 'x[0] <= 2.101\nfriedman_mse = 0.834\nsamples = 54\nvalue = 1.755'),
#  Text(0.35714285714285715, 0.3, 'x[7] <= 0.728\nfriedman_mse = 0.72\nsamples = 52\nvalue = 1.682'),
#  Text(0.32142857142857145, 0.1, 'friedman_mse = 0.825\nsamples = 42\nvalue = 1.74'),
#  Text(0.39285714285714285, 0.1, 'friedman_mse = 0.204\nsamples = 10\nvalue = 1.434'),
#  Text(0.5, 0.3, 'x[5] <= -0.042\nfriedman_mse = 0.026\nsamples = 2\nvalue = 3.662'),
#  Text(0.4642857142857143, 0.1, 'friedman_mse = 0.0\nsamples = 1\nvalue = 3.824'),
#  Text(0.5357142857142857, 0.1, 'friedman_mse = 0.0\nsamples = 1\nvalue = 3.5'),
#  Text(0.8035714285714286, 0.7, 'x[3] <= 2.282\nfriedman_mse = 1.576\nsamples = 5080\nvalue = 2.173'),
#  Text(0.7142857142857143, 0.5, 'x[1] <= 1.676\nfriedman_mse = 1.576\nsamples = 5074\nvalue = 2.174'),
#  Text(0.6428571428571429, 0.3, 'x[0] <= -1.401\nfriedman_mse = 1.375\nsamples = 3917\nvalue = 2.025'),
#  Text(0.6071428571428571, 0.1, 'friedman_mse = 0.367\nsamples = 80\nvalue = 1.028'),
#  Text(0.6785714285714286, 0.1, 'friedman_mse = 1.375\nsamples = 3837\nvalue = 2.046'),
#  Text(0.7857142857142857, 0.3, 'x[7] <= -2.098\nfriedman_mse = 1.929\nsamples = 1157\nvalue = 2.676'),
#  Text(0.75, 0.1, 'friedman_mse = 0.031\nsamples = 16\nvalue = 0.818'),
#  Text(0.8214285714285714, 0.1, 'friedman_mse = 1.907\nsamples = 1141\nvalue = 2.702'),
#  Text(0.8928571428571429, 0.5, 'x[7] <= -1.695\nfriedman_mse = 1.156\nsamples = 6\nvalue = 1.172'),
#  Text(0.8571428571428571, 0.3, 'friedman_mse = 0.0\nsamples = 1\nvalue = 0.15'),
#  Text(0.9285714285714286, 0.3, 'x[2] <= 7.083\nfriedman_mse = 1.136\nsamples = 5\nvalue = 1.377'),
#  Text(0.8928571428571429, 0.1, 'friedman_mse = 1.61\nsamples = 3\nvalue = 1.713'),
#  Text(0.9642857142857143, 0.1, 'friedman_mse = 0.0\nsamples = 2\nvalue = 0.872')]

# %%
from sklearn.datasets import load_diabetes

ds = load_diabetes()
X_train,X_test,y_train,y_test = train_test_split(ds.data,ds.target,test_size=0.2,random_state=7)
dtr.fit(X_train,y_train)

tree.plot_tree(dtr,filled=True)
# Out:
# [Text(0.4732142857142857, 0.9, 'x[6] <= 0.01\nfriedman_mse = 6150.412\nsamples = 353\nvalue = 154.099'),
#  Text(0.23214285714285715, 0.7, 'x[7] <= 0.008\nfriedman_mse = 5973.173\nsamples = 224\nvalue = 174.808'),
#  Text(0.14285714285714285, 0.5, 'x[3] <= -0.054\nfriedman_mse = 5818.03\nsamples = 109\nvalue = 152.266'),
#  Text(0.07142857142857142, 0.3, 'x[8] <= -0.032\nfriedman_mse = 1578.713\nsamples = 17\nvalue = 97.588'),
#  Text(0.03571428571428571, 0.1, 'friedman_mse = 236.806\nsamples = 6\nvalue = 59.167'),
#  Text(0.10714285714285714, 0.1, 'friedman_mse = 1066.248\nsamples = 11\nvalue = 118.545'),
#  Text(0.21428571428571427, 0.3, 'x[8] <= -0.05\nfriedman_mse = 5946.863\nsamples = 92\nvalue = 162.37'),
#  Text(0.17857142857142858, 0.1, 'friedman_mse = 2122.429\nsamples = 14\nvalue = 110.0'),
#  Text(0.25, 0.1, 'friedman_mse = 6052.69\nsamples = 78\nvalue = 171.769'),
#  Text(0.32142857142857145, 0.5, 'x[8] <= -0.069\nfriedman_mse = 5182.091\nsamples = 115\nvalue = 196.174'),
#  Text(0.2857142857142857, 0.3, 'friedman_mse = 0.0\nsamples = 1\nvalue = 69.0'),
#  Text(0.35714285714285715, 0.3, 'x[2] <= -0.006\nfriedman_mse = 5084.434\nsamples = 114\nvalue = 197.289'),
#  Text(0.32142857142857145, 0.1, 'friedman_mse = 4598.421\nsamples = 35\nvalue = 162.086'),
#  Text(0.39285714285714285, 0.1, 'friedman_mse = 4507.443\nsamples = 79\nvalue = 212.886'),
#  Text(0.7142857142857143, 0.7, 'x[2] <= 0.016\nfriedman_mse = 4420.399\nsamples = 129\nvalue = 118.14'),
#  Text(0.5714285714285714, 0.5, 'x[9] <= -0.124\nfriedman_mse = 3137.629\nsamples = 107\nvalue = 104.813'),
#  Text(0.5, 0.3, 'x[8] <= -0.054\nfriedman_mse = 717.556\nsamples = 3\nvalue = 87.333'),
#  Text(0.4642857142857143, 0.1, 'friedman_mse = 12.25\nsamples = 2\nvalue = 68.5'),
#  Text(0.5357142857142857, 0.1, 'friedman_mse = 0.0\nsamples = 1\nvalue = 125.0'),
#  Text(0.6428571428571429, 0.3, 'x[0] <= 0.054\nfriedman_mse = 3198.37\nsamples = 104\nvalue = 105.317'),
#  Text(0.6071428571428571, 0.1, 'friedman_mse = 2811.423\nsamples = 95\nvalue = 101.579'),
#  Text(0.6785714285714286, 0.1, 'friedman_mse = 5578.173\nsamples = 9\nvalue = 144.778'),
#  Text(0.8571428571428571, 0.5, 'x[5] <= -0.0\nfriedman_mse = 5594.589\nsamples = 22\nvalue = 182.955'),
#  Text(0.7857142857142857, 0.3, 'x[4] <= -0.009\nfriedman_mse = 3107.84\nsamples = 10\nvalue = 138.6'),
#  Text(0.75, 0.1, 'friedman_mse = 1434.776\nsamples = 7\nvalue = 124.286'),
#  Text(0.8214285714285714, 0.1, 'friedman_mse = 5418.0\nsamples = 3\nvalue = 172.0'),
#  Text(0.9285714285714286, 0.3, 'x[9] <= -0.025\nfriedman_mse = 4661.243\nsamples = 12\nvalue = 219.917'),
#  Text(0.8928571428571429, 0.1, 'friedman_mse = 0.0\nsamples = 1\nvalue = 103.0'),
#  Text(0.9642857142857143, 0.1, 'friedman_mse = 3729.339\nsamples = 11\nvalue = 230.545')]
