# %%
from sklearn.datasets import make_classification

X,y = make_classification(n_samples= 1000, n_features = 3, n_informative = 3,n_classes=2,n_redundant=0)
X
# Out:
# array([[ 0.27294831, -1.25999349,  1.07430608],
#        [-1.31423106, -0.27510138,  1.62828126],
#        [-1.54410407, -1.16847406, -0.38781032],
#        ...,
#        [-1.09755843, -0.79089856, -1.30285827],
#        [-0.72076291, -0.51569783, -0.330378  ],
#        [-1.05860511, -0.68647142,  1.31938487]])

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111,projection = '3d')
ax.scatter(X[:,0],X[:,1],X[:,2],c = y, cmap='viridis')

# %%
from sklearn.model_selection import train_test_split 
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=7)

from sklearn.neighbors import KNeighborsClassifier,kneighbors_graph
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_test_pred = knn.predict(X_test)
from sklearn.metrics import confusion_matrix,classification_report
print(confusion_matrix(y_test,y_test_pred))
print(classification_report(y_test,y_test_pred))
# Out:
# [[96  9]
#  [ 8 87]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.91      0.92       105
#            1       0.91      0.92      0.91        95
#
#     accuracy                           0.92       200
#    macro avg       0.91      0.92      0.91       200
# weighted avg       0.92      0.92      0.92       200
